# %% [markdown]
# <br>
# <br>
# <div style="text-align: center; font-weight: 700; font-size: 64px;">
#     Jaquet Droz
# </div>
# <br>
# <br>

# %% [markdown]
# <img src='R.png' style='max-width: 500px; height: 250px'>
# <br>
# <br>

# %% [markdown]
# <div>
#     <h1 > Team 1 </h1>
#     <h3>Team members</h3>
#     <ul>
#         <li>Maram Almasary</li>
#         <li>Hibah Sindi</li>
#         <li>Maha Alrooqi</li>
#     </ul>
#
#
# </div>

# %% [markdown]
# # Summary:
#
#
# - We used a tool called BeautifulSoup to extract information from the Jaquet Droz website. It helps us collect data from web pages.
#
# - The data we obtained consists of details on 131 watches. Each watch has 40 different features or characteristics that we gathered.
#
# - In some cases, certain features of the watches were not available or were missing. These features include information about the jewels used, frequency, clasp type, bracelet color, bracelet material, dial color, and water resistance.
#
# - Unfortunately, we couldn't retrieve information about the prices of the watches and the currency they are priced in. This information was not available on the website.

# %% [markdown]
# ## Steps we take to scrap the data from the website:
# - First, we visited the website and explored its structure to understand where the desired data is located.
#
# - Since the website was dynamic and required interaction, we initially attempted to use a tool called Selenium. We programmed Selenium to navigate through the pages, click on watches, and access their details. However, we encountered difficulties with extracting all the necessary information, particularly with the technical data section. The website utilized JavaScript scrolling to display additional details, which Selenium couldn't handle effectively within our limited timeframe.
#
# - To overcome this challenge, we opted for an alternative approach using BeautifulSoup. With BeautifulSoup, we scraped the required data in a more straightforward manner.
#
# - We began by scraping the links, titles, and image sources of each watch from the initial page. We stored this information in a list.
#
# - Next, we implemented a loop to visit each watch's individual page by following the links in the list.
#
# - Each watch's page contained additional watches, so we used NavigableString to search through the XML/HTML structure.
#
# - We implemented another loop to extract the image sources, links, and titles of the watches on the secondary page and added them to the existing lists.
#
# - We further iterated through each watch's link and accessed the page containing the technical details.
#
# - In this step, we retrieved the title and description of each watch and then extracted the technical details from the table. We parsed the rows and columns of the table and stored the information in a list.
#
# - We encountered another challenge when some watches had different color variations with distinct details. To address this, we revisited the HTML of the page to identify additional color variations, extract their links, and add them to the list of links.
#
# - By looping through these links, we were able to scrape the details of each color variation.
#
# - For some columns, we couldn't find the corresponding details on the website. In these cases, we marked those columns as null since the watches themselves didn't provide that information.
#
# - After collecting all the necessary details, we organized the data into a dataframe and saved it as a CSV file.
#
# - We then read the data from the CSV file and examined its structure.
#
# - The dataset consisted of 131 rows, numbered from 0 to 130, and contained 40 columns.
#
# - As we explored the data, we noticed that certain columns had missing values. These missing values indicate that the corresponding watches did not have those specific details available.
#
# - To investigate further, we analyzed the watches with missing values and discovered that those specific watches did not provide the information for those columns.

# %% [markdown]
# ### Challenges we faced:
# - The website is very complecated to descover, and as a user, it was a bit complex to find the details we want from it.
# - The website was dynamic and most of the things are done with javascript, and this was a bit hard to us to get the information.
# - Getting the details of the colors of some watches as this uses javascript to show each page for movement.
# - Learning about web scrapping in a short period of time.

# %% [markdown]
# ### Things we noticed:
# - The watches do not have prices.
# - There are not a lot of details about each watch.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Importing the neccessary libraries

# %%
# Import necessary libraries and modules for data manipulation, visualization, web scraping, and regular expressions.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import requests
from bs4 import BeautifulSoup, NavigableString
import pandas as pd
import re

# %% [markdown]
# ### Extracting Data using BeautifulSoup

# %%
def extract_asoup(url, parser='lxml'):
  # Send a GET request to the specified 'url' and retrieve the page content
  page = requests.get(url)
  
  # Create a BeautifulSoup object by parsing the 'page.content' using the specified 'parser'
  soup = BeautifulSoup(page.content, parser)
  
  # Return the resulting BeautifulSoup object
  return soup

# %%
#Assigning the link to the website to a variable
watches_url = "https://www.jaquet-droz.com/en/watches"

# %%
# Extract the HTML content from the specified 'watches_url' and parse it using 'html.parser'
soup = extract_asoup(watches_url, 'html.parser')

# %% [markdown]
# ### Extract Watch URLs

# %%
# Find all the <a> tags (hyperlinks) in the parsed HTML using BeautifulSoup
links = soup.find_all('a', href=True)

# Extract the URLs from the <a> tags that start with "https://www.jaquet-droz.com/en/watches/"
watches_urls = [link['href'] for link in links if link['href'].startswith("https://www.jaquet-droz.com/en/watches/")]

#Let's see the links we have extract 
watches_urls
# Out:
# ['https://www.jaquet-droz.com/en/watches/timepieces',
#  'https://www.jaquet-droz.com/en/watches/automata',
#  'https://www.jaquet-droz.com/en/watches/ateliers-d-art',
#  'https://www.jaquet-droz.com/en/watches/grande-seconde',
#  'https://www.jaquet-droz.com/en/watches/sw',
#  'https://www.jaquet-droz.com/en/watches/petite-heure-minute',
#  'https://www.jaquet-droz.com/en/watches/lady-8',
#  'https://www.jaquet-droz.com/en/watches/astrale']

# %%
all_watches = []
sub_category = []
for watch_url in watches_urls:
    # Extract the watch details from the URL
    watch_soup = extract_asoup(watch_url, 'html.parser')
    content = watch_soup.find('div', class_ = 'block block-system')
#     print(print(watch_url))
    
    # Skip to the next iteration if content is None
    if content is None:
        continue
     # Extract the parent model information
    parent_model = content.find('h1').text
    count = 1
    # Extract the URLs of related watches
    item_list = content.find_all('a', href=True)
    urls =[link['href'] for link in item_list]
#     print(len(urls))
    
    for watch in urls:
        watch_URL = watch
        all_watches.append(watch_URL)
        
#         variante
        
#         print(watch_URL)
        # Extract the watch information from the related watch URL
        watch_infos = extract_asoup(watch, 'html.parser')
        watch_info = watch_infos.find('div', class_ = 'watch-infos')
#         print(watch_info)
        lis = watch_info.find_all('li', class_ = 'variante')
        for li in lis:
            a_tag = li.find('a')
            if a_tag:
                
                href = a_tag['href']
                sub_category.append(href)
                all_watches.append(href)
                
                # Find the <img> tag within the <a> tag
                img_tag = a_tag.find('img')
                
                # Check if the <img> tag exists
                if img_tag:
                    # Extract the value of the 'src' attribute
                    image_url = img_tag['src']
#                 print(href)
        
# print(len(all_watches))
# print(len(all_watches))
# Out:
# 131

# %%
watches_data = []
for all_w in all_watches:
#     watchs_links = extract_asoup(all_w, 'html.parser')
    watch_infos = extract_asoup(all_w, 'html.parser')
    watch_info = watch_infos.find('div', class_ = 'watch-infos')
    
    
     # Extract various details of the watch
    specific_model = watch_info.find('h1', class_ = 'title-node').text
    description = watch_info.find('div', class_ = 'description').text.strip()
    watch_spec = watch_info.find('div', class_ = 'watch-spec')
    features = watch_spec.find('th', text='Indications').find_next_sibling('td').text if watch_spec.find('th', text='Indications') else None
    jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text \
        if watch_spec.find('th', text='Jewelling') else None
    frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else None
    power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else None
    caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else None
    movement = caliber
    clasp_type = watch_spec.find('th', text='Buckle').find_next_sibling('td').text if watch_spec.find('th', text='Buckle') else None
    bracelet_color = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else None
    bracelet_material = bracelet_color
    dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else None
    water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text if watch_spec.find('th', text=lambda text: text and 'resistance' in text) else None
    case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else None
    diameter = case_thickness
    case_material = case_thicknes  
    image_URL = watch_infos.find('div', class_='watch-picture').find('img').get('src')
    price =""
    currency = ""
    brand = "Jaquet Droz"
    reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text
    
    
    watches_data.append({
            
            "reference_number": reference_number,
            "watch_URL": watch_URL,
            "type": '',
            "brand": brand,
            "year_introduced": '',
            "parent_model": parent_model,
            "specific_model": specific_model,
            "nickname": '',
            "marketing_name": '',
            "style": '',
            "currency": currency,
            "price": price,
            "image_URL": image_URL,
            "made_in": '',
            "case_shape": '',
            "case_material": case_material,
            "case_finish": '',
            "caseback": '',
            "diameter": diameter,
            "between_lugs": '',
            "lug_to_lug": '',
            "case_thickness": case_thickness,
            "bezel_material": '',
            "bezel_color": '',
            "crystal": '',
            "water_resistance": water_resistance,
            "weight": '',
            "dial_color": dial_color,
            "numerals": '',
            "bracelet_material": bracelet_material,
            "bracelet_color": bracelet_color,
            "clasp_type": clasp_type,
            "movement": caliber,
            "caliber": caliber,
           "power_reserve": power_reserve,
           "frequency": frequency,
           "jewels": jewels,
           "features": features,
           "description": description,
           "short_description": ''
        })
    
    
    
    print(reference_number)

# %%
#Creating a dataframe (watches details) from the data we got from the website
df_watches_data = pd.DataFrame(watches_data)

#Seeing the dataframe (watches details)
df_watches_data

# %%
#Creating a empty list to save the data of the watches in it
watches_data = []
sub_category = []
# Loop through each watch URL
for watch_url in watches_urls:
    # Extract the watch details from the URL
    watch_soup = extract_asoup(watch_url, 'html.parser')
    content = watch_soup.find('div', class_ = 'block block-system')
    
    # Skip to the next iteration if content is None
    if content is None:
        continue
        
    # Extract the parent model information
    parent_model = content.find('h1').text
    count = 1
    # Extract the URLs of related watches
    item_list = content.find_all('a', href=True)
    urls =[link['href'] for link in item_list]
    print(urls)
    
    # Loop through each related watch URL
    for watch in urls:
        watch_URL = watch
#         variante
        
#         print(watch_URL)
        # Extract the watch information from the related watch URL
        watch_infos = extract_asoup(watch, 'html.parser')
        watch_info = watch_infos.find('div', class_ = 'watch-infos')
        lis = watch_info.find_all('li', class_ = 'variante')
        
        for li_elem in lis:
            ass = li_elem.find_all('a')
            for a in ass:
                sub_category.append(a)
#                 print(a['href'])
#             li_elem.find_all('a')
#             print(ass)
#             print(li_elem)
        
#         print(sub_category)
        if count == 2:
            break
        
        count = 2
        # Extract various details of the watch
        specific_model = watch_info.find('h1', class_ = 'title-node').text
        description = watch_info.find('div', class_ = 'description').text.strip()
        watch_spec = watch_info.find('div', class_ = 'watch-spec')
        features = watch_spec.find('th', text='Indications').find_next_sibling('td').text if watch_spec.find('th', text='Indications') else None
        jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text \
            if watch_spec.find('th', text='Jewelling') else None
        frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else None
        power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else None
        caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else None
        movement = caliber
        clasp_type = watch_spec.find('th', text='Buckle').find_next_sibling('td').text if watch_spec.find('th', text='Buckle') else None
        bracelet_color = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else None
        bracelet_material = bracelet_color
        dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else None
        water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text if watch_spec.find('th', text=lambda text: text and 'resistance' in text) else None
        case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else None
        diameter = case_thickness
        case_material = case_thickness

        image_URL = watch_infos.find('div', class_='watch-picture').find('img').get('src')
        price =""
        currency = ""
        brand = "Jaquet Droz"
        reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text
        
        
         # Update the list of URLs based on variant colors
#         if watch_infos.select('div.variantes li.variante:not(.active)'):
#             list_colors = [li.find('a')['href'] for li in watch_infos.select('div.variantes li.variante:not(.active)')]

#             index = urls.index(watch)
#             urls[index:index] = [item for item in list_colors if item not in urls]



        # Append the extracted watch data to the watches_data list
        watches_data.append({
            
            "reference_number": reference_number,
            "watch_URL": watch_URL,
            "type": '',
            "brand": brand,
            "year_introduced": '',
            "parent_model": parent_model,
            "specific_model": specific_model,
            "nickname": '',
            "marketing_name": '',
            "style": '',
            "currency": currency,
            "price": price,
            "image_URL": image_URL,
            "made_in": '',
            "case_shape": '',
            "case_material": case_material,
            "case_finish": '',
            "caseback": '',
            "diameter": diameter,
            "between_lugs": '',
            "lug_to_lug": '',
            "case_thickness": case_thickness,
            "bezel_material": '',
            "bezel_color": '',
            "crystal": '',
            "water_resistance": water_resistance,
            "weight": '',
            "dial_color": dial_color,
            "numerals": '',
            "bracelet_material": bracelet_material,
            "bracelet_color": bracelet_color,
            "clasp_type": clasp_type,
            "movement": caliber,
            "caliber": caliber,
           "power_reserve": power_reserve,
           "frequency": frequency,
           "jewels": jewels,
           "features": features,
           "description": description,
           "short_description": ''
        })
# Out:
# ['https://www.jaquet-droz.com/en/watches/automata/the-rolling-stones-automaton-j0328330011', 'https://www.jaquet-droz.com/en/watches/grande-seconde/grande-seconde-skelet-one-tourbillon-j013523242', 'https://www.jaquet-droz.com/en/watches/grande-seconde/tourbillon-skelet-skull-j0135230011', 'https://www.jaquet-droz.com/en/watches/grande-seconde/tourbillon-skelet-ceramic-j0135250061', 'https://www.jaquet-droz.com/en/watches/grande-seconde/tourbillon-skelet-sapphire-j0135270021', 'https://www.jaquet-droz.com/en/watches/automata/dragon-automaton-j0327370011', 'https://www.jaquet-droz.com/en/watches/automata/bird-repeater-300th-anniversary-edition-j031033211', 'https://www.jaquet-droz.com/en/watches/automata/the-charming-bird', 'https://www.jaquet-droz.com/en/watches/automata/loving-butterfly-automaton-j032533275', 'https://www.jaquet-droz.com/en/watches/automata/magic-lotus-automaton-j032633270', 'https://www.jaquet-droz.com/en/watches/automata/tropical-bird-repeater-j033033202', 'https://www.jaquet-droz.com/en/watches/automata/lady-8-flower-J032004201', 'https://www.jaquet-droz.com/en/watches/ateliers-d-art/relief-petite-heure-minute-tiger-j005024288', 'https://www.jaquet-droz.com/en/watches/ateliers-d-art/grande-seconde-tourbillon-paillonnee-j013033243', 'https://www.jaquet-droz.com/en/watches/grande-seconde/grande-seconde-minute-repeater', 'https://www.jaquet-droz.com/en/watches/grande-seconde/grande-seconde-tourbillon-ivory-enamel', 'https://www.jaquet-droz.com/en/watches/sw/tourbillon-sw', 'https://www.jaquet-droz.com/en/watches/automata/signing-machine-j899-000-064', 'https://www.jaquet-droz.com/en/watches/automata/whistling-machine-j899.000.070', 'https://www.jaquet-droz.com/en/watches/automata/the-poet-automaton-j899-000-052']
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:51: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   features = watch_spec.find('th', text='Indications').find_next_sibling('td').text if watch_spec.find('th', text='Indications') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:53: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   if watch_spec.find('th', text='Jewelling') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:52: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text \
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:54: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:55: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:56: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:58: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   clasp_type = watch_spec.find('th', text='Buckle').find_next_sibling('td').text if watch_spec.find('th', text='Buckle') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:59: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   bracelet_color = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:61: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:62: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text if watch_spec.find('th', text=lambda text: text and 'resistance' in text) else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:63: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\2518073289.py:71: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text
# ['https://www.jaquet-droz.com/en/watches/automata/the-rolling-stones-automaton-j0328330011', 'https://www.jaquet-droz.com/en/watches/automata/the-bird-repeater-alpine-view', 'https://www.jaquet-droz.com/en/watches/automata/dragon-automaton-j0327370011', 'https://www.jaquet-droz.com/en/watches/automata/the-charming-bird', 'https://www.jaquet-droz.com/en/watches/automata/loving-butterfly-automaton-j032533275', 'https://www.jaquet-droz.com/en/watches/automata/magic-lotus-automaton-j032633270', 'https://www.jaquet-droz.com/en/watches/automata/tropical-bird-repeater-j033033202', 'https://www.jaquet-droz.com/en/watches/automata/lady-8-flower-J032003200', 'https://www.jaquet-droz.com/en/watches/automata/signing-machine-j899-000-064', 'https://www.jaquet-droz.com/en/watches/automata/whistling-machine-j899.000.070']
# ['https://www.jaquet-droz.com/en/watches/ateliers-d-art/grande-seconde-tourbillon-paillonnee-j013033243']
# ['https://www.jaquet-droz.com/en/watches/grande-seconde/grande-seconde-skelet-one-tourbillon-j013523242', 'https://www.jaquet-droz.com/en/watches/grande-seconde/tourbillon-skelet-skull-j0135230011', 'https://www.jaquet-droz.com/en/watches/grande-seconde/tourbillon-skelet-ceramic-j0135250061', 'https://www.jaquet-droz.com/en/watches/grande-seconde/tourbillon-skelet-sapphire-j0135270021', 'https://www.jaquet-droz.com/en/watches/grande-seconde/grande-seconde-minute-repeater', 'https://www.jaquet-droz.com/en/watches/grande-seconde/grande-seconde-tourbillon-ivory-enamel-0']
# ['https://www.jaquet-droz.com/en/watches/sw/tourbillon-sw']
# []
# []
# []

# %%
# Creating an empty list to save the data of the watches in it
watches_data = []

# Loop through each watch URL
for watch_url in watches_urls:
    # Extract the watch details from the URL
    watch_soup = extract_asoup(watch_url, 'html.parser')
    content = watch_soup.find('div', class_='block block-system')
    
    # Skip to the next iteration if content is None
    if content is None:
        continue
        
    # Extract the parent model information
    parent_model = content.find('h1').text
    
    # Extract the URLs of related watches
    item_list = content.find_all('a', href=True)
    urls = [link['href'] for link in item_list]
    
    # Loop through each related watch URL
    for watch in urls:
        watch_URL = watch
        
        # Extract the watch information from the related watch URL
        watch_infos = extract_asoup(watch, 'html.parser')
    
        # Check if the watch is not active and extract data from variant colors
        if watch_infos.select('div.variantes li.variante:not(.active)'):
            list_colors = [li.find('a')['href'] for li in watch_infos.select('div.variantes li.variante:not(.active)')]
            for color_url in list_colors:
                color_soup = extract_asoup(color_url, 'html.parser')
                color_content = color_soup.find('div', class_='block block-system')
                
                # Skip to the next iteration if color_content is None
                if color_content is None:
                    continue
                
                # Extract the color-specific watch information
                color_specific_info = color_content.find('div', class_='watch-infos')
                
                # Skip to the next iteration if color_specific_info is None
                if color_specific_info is None:
                    continue
                
         # Extract various details of the watch for the particular color
        specific_model = color_specific_info.find('h1', class_='title-node').text
        description = color_specific_info.find('div', class_='description').text.strip()
        watch_spec = color_specific_info.find('div', class_='watch-spec')
        # Extract other details for the particular color
        caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else None
        power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else None
        frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else None
        jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text if watch_spec.find('th', text='Jewelling') else None
        bracelet_material = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else None
        dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else None
        water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text if watch_spec.find('th', text=lambda text: text and 'resistance' in text) else None
        case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else None
        diameter = case_thickness
        case_material = case_thickness   
        image_div = color_specific_info.find('div', class_='watch-picture')
        image_URL = image_div.find('img')['src'] if image_div and image_div.find('img') else None
        price = ""
        currency = ""
        brand = "Jaquet Droz"
        reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text   
        # Append the extracted watch data to the watches_data list for the particular color
        watches_data.append({
            "reference_number": reference_number,
            "watch_URL": watch_URL,
             "type": '',
             "brand":brand,
             "year_introduced": '',
             "parent_model": parent_model,
             "specific_model": specific_model,
             "nickname": '',
             "marketing_name": '',
             "style": '',
             "currency": currency,
             "price": price,
             "image_URL": image_URL,
             "made_in": '',
             "case_shape": '',
             "case_material": case_material,
             "case_finish": '',
             "caseback": '',
             "diameter": diameter,
             "between_lugs": '',
             "lug_to_lug": '',
             "case_thickness": case_thickness,
             "bezel_material": '',
             "bezel_color": '',
             "crystal": '',
             "water_resistance": water_resistance,
             "weight": '',
             "dial_color": dial_color,
             "numerals": '',
             "bracelet_material": bracelet_material,
             "bracelet_color": bracelet_color,
             "clasp_type": clasp_type,
             "movement": caliber,
             "caliber": caliber,
             "power_reserve": power_reserve,
             "frequency": frequency,
             "jewels": jewels,
             "features": features,
             "description": description,
             "short_description": '',  
         })
# Out:
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\919732427.py:51: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\919732427.py:52: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\919732427.py:53: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\919732427.py:54: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text if watch_spec.find('th', text='Jewelling') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\919732427.py:55: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   bracelet_material = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\919732427.py:56: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\919732427.py:57: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text if watch_spec.find('th', text=lambda text: text and 'resistance' in text) else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\919732427.py:58: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_30956\919732427.py:66: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text

# %%
#Creating a dataframe (watches details) from the data we got from the website
df_watches_data = pd.DataFrame(watches_data)

#Seeing the dataframe (watches details)
df_watches_data
# Out:
#     reference_number                                          watch_URL type  \
# 0        J0328330011  https://www.jaquet-droz.com/en/watches/automat...
# 1        J0328330151  https://www.jaquet-droz.com/en/watches/automat...
# 2         J013523242  https://www.jaquet-droz.com/en/watches/grande-...
# 3        J0135240021  https://www.jaquet-droz.com/en/watches/grande-...
# 4        J0135230011  https://www.jaquet-droz.com/en/watches/grande-...
# ..               ...                                                ...  ...
# 126       J013014270  https://www.jaquet-droz.com/en/watches/grande-...
# 127       J013014271  https://www.jaquet-droz.com/en/watches/grande-...
# 128       J013013580  https://www.jaquet-droz.com/en/watches/grande-...
# 129       J013013281  https://www.jaquet-droz.com/en/watches/grande-...
# 130       J030033240  https://www.jaquet-droz.com/en/watches/sw/tour...
#
#            brand year_introduced    parent_model  \
# 0    Jaquet Droz                      Timepieces
# 1    Jaquet Droz                      Timepieces
# 2    Jaquet Droz                      Timepieces
# 3    Jaquet Droz                      Timepieces
# 4    Jaquet Droz                      Timepieces
# ..           ...             ...             ...
# 126  Jaquet Droz                  GRANDE SECONDE
# 127  Jaquet Droz                  GRANDE SECONDE
# 128  Jaquet Droz                  GRANDE SECONDE
# 129  Jaquet Droz                  GRANDE SECONDE
# 130  Jaquet Droz                              SW
#
#                    specific_model nickname marketing_name style  ...  \
# 0    The Rolling Stones Automaton                                ...
# 1    The Rolling Stones Automaton                                ...
# 2               Tourbillon Skelet                                ...
# 3               Tourbillon Skelet                                ...
# 4         Tourbillon Skelet Skull                                ...
# ..                            ...      ...            ...   ...  ...
# 126         Tourbillon Aventurine                                ...
# 127    Tourbillon Blue Pietersite                                ...
# 128    Tourbillon Mother-of-pearl                                ...
# 129            Tourbillon Jadeite                                ...
# 130                 Tourbillon SW                                ...
#
#                                         bracelet_color  \
# 0               Fabric with printed patterns in rubber
# 1               Fabric with printed patterns in rubber
# 2                Rolled-edge hand-made black alligator
# 3                Rolled-edge hand-made black alligator
# 4                                         Rubber strap
# ..                                                 ...
# 126  Rolled-edge hand-made black alligator leather ...
# 127  Rolled-edge hand-made black alligator leather ...
# 128  Rolled-edge hand-made black alligator leather ...
# 129  Rolled-edge hand-made black alligator leather ...
# 130  Rolled-edge hand made inserted black alligator...
#
#                                             clasp_type  \
# 0                      18-karat red gold folding clasp
# 1                      18-karat red gold folding clasp
# 2                      18-karat red gold folding clasp
# 3                      18-karat red gold folding clasp
# 4                      18-karat red gold folding clasp
# ..                                                 ...
# 126                    18-carat red gold folding clasp
# 127                    18-carat red gold folding clasp
# 128                    18-carat red gold folding clasp
# 129                    18-carat red gold folding clasp
# 130  18-carat red gold folding clasp with black PVD...
#
#                                               movement  \
# 0    Jaquet Droz 2653 AT2, self-winding mechanical ...
# 1    Jaquet Droz 2653 AT2, self-winding mechanical ...
# 2    Jaquet Droz 2625SQ, self-winding skeleton tour...
# 3    Jaquet Droz 2625SQ, self-winding skeleton tour...
# 4    Jaquet Droz 2625SQ, self-winding skeleton tour...
# ..                                                 ...
# 126  Jaquet Droz 25JD, self-winding tourbillon move...
# 127  Jaquet Droz 25JD, self-winding tourbillon move...
# 128  Jaquet Droz 25JD.Si, self-winding tourbillon m...
# 129  Jaquet Droz 25JD, self-winding tourbillon move...
# 130  Jaquet Droz 25JD-S, self-winding tourbillon mo...
#
#                                                caliber power_reserve  \
# 0    Jaquet Droz 2653 AT2, self-winding mechanical ...      68 hours
# 1    Jaquet Droz 2653 AT2, self-winding mechanical ...      68 hours
# 2    Jaquet Droz 2625SQ, self-winding skeleton tour...        7 days
# 3    Jaquet Droz 2625SQ, self-winding skeleton tour...        7 days
# 4    Jaquet Droz 2625SQ, self-winding skeleton tour...        7 days
# ..                                                 ...           ...
# 126  Jaquet Droz 25JD, self-winding tourbillon move...        7 days
# 127  Jaquet Droz 25JD, self-winding tourbillon move...        7 days
# 128  Jaquet Droz 25JD.Si, self-winding tourbillon m...        7 days
# 129  Jaquet Droz 25JD, self-winding tourbillon move...        7 days
# 130  Jaquet Droz 25JD-S, self-winding tourbillon mo...        7 days
#
#          frequency             jewels  \
# 0    28,800 v.p.h.          56 jewels
# 1    28,800 v.p.h.          56 jewels
# 2    21,600 v.p.h.          30 jewels
# 3    21,600 v.p.h.          30 jewels
# 4    21,600 v.p.h.          30 jewels
# ..             ...                ...
# 126   21,600 v.p.h      31 jewels\r\n
# 127   21,600 v.p.h  31 jewels\r\n\r\n
# 128   21,600 v.p.h          31 jewels
# 129  21,600 v.p.h.          31 jewels
# 130   21,600 v.p.h          31 jewels
#
#                                               features  \
# 0                       Off-centered hours and minutes
# 1                       Off-centered hours and minutes
# 2    Off-centered hours and minutes at 6 o'clock. T...
# 3    Off-centered hours and minutes at 6 o'clock. T...
# 4    Off-centered hours and minutes at 6 o'clock. T...
# ..                                                 ...
# 126  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 127  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 128  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 129  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 130  Hours and minutes at 6 o'clock\r\nTourbillon f...
#
#                                            description short_description
# 0    Black onyx dial and 18-karat red gold applied ...
# 1    Black onyx dial and 18-karat red gold applied ...
# 2    Sapphire dial with metallic sapphire base. \r\...
# 3    Transparent sapphire dial and blue sapphire ba...
# 4    Hand-engraved and hand-painted 18-karat gold d...
# ..                                                 ...               ...
# 126  Aventurine dial with white gold diamond-set ri...
# 127  Blue pietersite dial with white mother-of-pear...
# 128  White mother-of-pearl dial. \r\n18-karat red g...
# 129  Jadeite dial, white mother-of-pearl subdial. \...
# 130  Black dial with rubber treatment.\r\n18-carat ...
#
# [131 rows x 40 columns]

# %%
df[df_watches_data['reference_number'] == 'J0135240021']
# Out:
#     reference_number                                          watch_URL  type  \
# 3        J0135240021  https://www.jaquet-droz.com/en/watches/grande-...   NaN
# 108      J0135240021  https://www.jaquet-droz.com/en/watches/grande-...   NaN
#
#            brand  year_introduced    parent_model     specific_model  \
# 3    Jaquet Droz              NaN      Timepieces  Tourbillon Skelet
# 108  Jaquet Droz              NaN  GRANDE SECONDE  Tourbillon Skelet
#
#      nickname  marketing_name  style  ...  \
# 3         NaN             NaN    NaN  ...
# 108       NaN             NaN    NaN  ...
#
#                             bracelet_color                       clasp_type  \
# 3    Rolled-edge hand-made black alligator  18-karat red gold folding clasp
# 108  Rolled-edge hand-made black alligator  18-karat red gold folding clasp
#
#                                               movement  \
# 3    Jaquet Droz 2625SQ, self-winding skeleton tour...
# 108  Jaquet Droz 2625SQ, self-winding skeleton tour...
#
#                                                caliber  power_reserve  \
# 3    Jaquet Droz 2625SQ, self-winding skeleton tour...         7 days
# 108  Jaquet Droz 2625SQ, self-winding skeleton tour...         7 days
#
#          frequency     jewels  \
# 3    21,600 v.p.h.  30 jewels
# 108  21,600 v.p.h.  30 jewels
#
#                                               features  \
# 3    Off-centered hours and minutes at 6 o'clock. T...
# 108  Off-centered hours and minutes at 6 o'clock. T...
#
#                                            description  short_description
# 3    Transparent sapphire dial and blue sapphire ba...                NaN
# 108  Transparent sapphire dial and blue sapphire ba...                NaN
#
# [2 rows x 40 columns]

# %%
#Converting (Saving) the dataframe (watches data) in a csv file

df_watches_data.to_csv('df_watches_data3.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# <hr>

# %%
#Reading the data from a csv file
df = pd.read_csv('df_watches_data3.csv')

#Seeing the dataframe
df.head()
# Out:
#   reference_number                                          watch_URL  type  \
# 0      J0328330011  https://www.jaquet-droz.com/en/watches/automat...   NaN
# 1      J0328330151  https://www.jaquet-droz.com/en/watches/automat...   NaN
# 2       J013523242  https://www.jaquet-droz.com/en/watches/grande-...   NaN
# 3      J0135240021  https://www.jaquet-droz.com/en/watches/grande-...   NaN
# 4      J0135230011  https://www.jaquet-droz.com/en/watches/grande-...   NaN
#
#          brand  year_introduced parent_model                specific_model  \
# 0  Jaquet Droz              NaN   Timepieces  The Rolling Stones Automaton
# 1  Jaquet Droz              NaN   Timepieces  The Rolling Stones Automaton
# 2  Jaquet Droz              NaN   Timepieces             Tourbillon Skelet
# 3  Jaquet Droz              NaN   Timepieces             Tourbillon Skelet
# 4  Jaquet Droz              NaN   Timepieces       Tourbillon Skelet Skull
#
#    nickname  marketing_name  style  ...  \
# 0       NaN             NaN    NaN  ...
# 1       NaN             NaN    NaN  ...
# 2       NaN             NaN    NaN  ...
# 3       NaN             NaN    NaN  ...
# 4       NaN             NaN    NaN  ...
#
#                            bracelet_color                       clasp_type  \
# 0  Fabric with printed patterns in rubber  18-karat red gold folding clasp
# 1  Fabric with printed patterns in rubber  18-karat red gold folding clasp
# 2   Rolled-edge hand-made black alligator  18-karat red gold folding clasp
# 3   Rolled-edge hand-made black alligator  18-karat red gold folding clasp
# 4                            Rubber strap  18-karat red gold folding clasp
#
#                                             movement  \
# 0  Jaquet Droz 2653 AT2, self-winding mechanical ...
# 1  Jaquet Droz 2653 AT2, self-winding mechanical ...
# 2  Jaquet Droz 2625SQ, self-winding skeleton tour...
# 3  Jaquet Droz 2625SQ, self-winding skeleton tour...
# 4  Jaquet Droz 2625SQ, self-winding skeleton tour...
#
#                                              caliber  power_reserve  \
# 0  Jaquet Droz 2653 AT2, self-winding mechanical ...       68 hours
# 1  Jaquet Droz 2653 AT2, self-winding mechanical ...       68 hours
# 2  Jaquet Droz 2625SQ, self-winding skeleton tour...         7 days
# 3  Jaquet Droz 2625SQ, self-winding skeleton tour...         7 days
# 4  Jaquet Droz 2625SQ, self-winding skeleton tour...         7 days
#
#        frequency     jewels  \
# 0  28,800 v.p.h.  56 jewels
# 1  28,800 v.p.h.  56 jewels
# 2  21,600 v.p.h.  30 jewels
# 3  21,600 v.p.h.  30 jewels
# 4  21,600 v.p.h.  30 jewels
#
#                                             features  \
# 0                     Off-centered hours and minutes
# 1                     Off-centered hours and minutes
# 2  Off-centered hours and minutes at 6 o'clock. T...
# 3  Off-centered hours and minutes at 6 o'clock. T...
# 4  Off-centered hours and minutes at 6 o'clock. T...
#
#                                          description  short_description
# 0  Black onyx dial and 18-karat red gold applied ...                NaN
# 1  Black onyx dial and 18-karat red gold applied ...                NaN
# 2  Sapphire dial with metallic sapphire base. \r\...                NaN
# 3  Transparent sapphire dial and blue sapphire ba...                NaN
# 4  Hand-engraved and hand-painted 18-karat gold d...                NaN
#
# [5 rows x 40 columns]

# %%
df['reference_number'].value_counts()
# Out:
# reference_number
# J0328330011     2
# J0328330151     2
# J032533275      2
# J032534271      2
# J032534270      2
#                ..
# J0327370021     2
# J0327330061     2
# J005023300      1
# J005024288      1
# J899.000.052    1
# Name: count, Length: 67, dtype: int64

# %%
df[df['reference_number'] == 'J899']
# Out:
# Empty DataFrame
# Columns: [reference_number, watch_URL, type, brand, year_introduced, parent_model, specific_model, nickname, marketing_name, style, currency, price, image_URL, made_in, case_shape, case_material, case_finish, caseback, diameter, between_lugs, lug_to_lug, case_thickness, bezel_material, bezel_color, crystal, water_resistance, weight, dial_color, numerals, bracelet_material, bracelet_color, clasp_type, movement, caliber, power_reserve, frequency, jewels, features, description, short_description]
# Index: []
#
# [0 rows x 40 columns]

# %%
#Seeing the info our the watches
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reference_number   131 non-null    object
#  1   watch_URL          131 non-null    object
#  2   type               0 non-null      float64
#  3   brand              131 non-null    object
#  4   year_introduced    0 non-null      float64
#  5   parent_model       131 non-null    object
#  6   specific_model     131 non-null    object
#  7   nickname           0 non-null      float64
#  8   marketing_name     0 non-null      float64
#  9   style              0 non-null      float64
#  10  currency           0 non-null      float64
#  11  price              0 non-null      float64
#  12  image_URL          131 non-null    object
#  13  made_in            0 non-null      float64
#  14  case_shape         0 non-null      float64
#  15  case_material      131 non-null    object
#  16  case_finish        0 non-null      float64
#  17  caseback           0 non-null      float64
#  18  diameter           131 non-null    object
#  19  between_lugs       0 non-null      float64
#  20  lug_to_lug         0 non-null      float64
#  21  case_thickness     131 non-null    object
#  22  bezel_material     0 non-null      float64
#  23  bezel_color        0 non-null      float64
#  24  crystal            0 non-null      float64
#  25  water_resistance   124 non-null    object
#  26  weight             0 non-null      float64
#  27  dial_color         126 non-null    object
#  28  numerals           0 non-null      float64
#  29  bracelet_material  126 non-null    object
#  30  bracelet_color     126 non-null    object
#  31  clasp_type         126 non-null    object
#  32  movement           131 non-null    object
#  33  caliber            131 non-null    object
#  34  power_reserve      131 non-null    object
#  35  frequency          126 non-null    object
#  36  jewels             128 non-null    object
#  37  features           126 non-null    object
#  38  description        131 non-null    object
#  39  short_description  0 non-null      float64
# dtypes: float64(19), object(21)
# memory usage: 41.1+ KB

# %%
#Checking for the null (missing) features in our watches' data
df.isna().sum()
#We can notice that, some of the watches do not have some features and the website did not put them as No. 
#So, because of that they are missing
# Out:
# reference_number       0
# watch_URL              0
# type                 131
# brand                  0
# year_introduced      131
# parent_model           0
# specific_model         0
# nickname             131
# marketing_name       131
# style                131
# currency             131
# price                131
# image_URL              0
# made_in              131
# case_shape           131
# case_material          0
# case_finish          131
# caseback             131
# diameter               0
# between_lugs         131
# lug_to_lug           131
# case_thickness         0
# bezel_material       131
# bezel_color          131
# crystal              131
# water_resistance       7
# weight               131
# dial_color             5
# numerals             131
# bracelet_material      5
# bracelet_color         5
# clasp_type             5
# movement               0
# caliber                0
# power_reserve          0
# frequency              5
# jewels                 3
# features               5
# description            0
# short_description    131
# dtype: int64

# %% [markdown]
# <hr>
