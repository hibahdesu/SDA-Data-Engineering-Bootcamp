# %%
import pandas as pd

# %%
df = pd.read_csv('df_watches_data2.csv')
df
# Out:
#     field name                             reference_number  \
# 0        value                                  J0328330011
# 1        value                                  J0328330011
# 2        value                                   J013523242
# 3        value                                   J013523242
# 4        value                                  J0135230011
# ..         ...                                          ...
# 127      value                                   J013013580
# 128      value                                   J013013281
# 129      value                                   J013033200
# 130      value                                   J030033240
# 131      value  Listed under "Technical Data" > "Reference"
#
#                                              watch_URL  type        brand  \
# 0    https://www.jaquet-droz.com/en/watches/automat...   NaN  Jaquet Droz
# 1    https://www.jaquet-droz.com/en/watches/automat...   NaN  Jaquet Droz
# ...

# %%
df.columns
# Out:
# Index(['field name', 'reference_number', 'watch_URL', 'type', 'brand',
#        'year_introduced', 'parent_model', 'specific_model', 'nickname',
#        'marketing_name', 'style', 'currency', 'price', 'image_URL', 'made_in',
#        'case_shape', 'case_material', 'case_finish', 'caseback', 'diameter',
#        'between_lugs', 'lug_to_lug', 'case_thickness', 'bezel_material',
#        'bezel_color', 'crystal', 'water_resistance', 'weight', 'dial_color',
#        'numerals', 'bracelet_material', 'bracelet_color', 'clasp_type',
#        'caliber', 'power_reserve', 'frequency', 'jewels', 'features',
#        'description', 'short_description'],
#       dtype='object')

# %%
df['watch_URL'].isna().sum()
# Out:
# 1

# %%
df.shape
# Out:
# (132, 40)

# %%
df[df['water_resistance'].isna()]
# Out:
#     field name reference_number  \
# 55       value       J011033202
# 64       value     J899.000.064
# 65       value     J899.000.070
# 66       value     J899.000.052
# 104      value     J899.000.064
# 105      value     J899.000.070
# 122      value       J011033202
#
#                                              watch_URL  type        brand  \
# 55   https://www.jaquet-droz.com/en/watches/grande-...   NaN  Jaquet Droz
# 64   https://www.jaquet-droz.com/en/watches/automat...   NaN  Jaquet Droz
# 65   https://www.jaquet-droz.com/en/watches/automat...   NaN  Jaquet Droz
# 66   https://www.jaquet-droz.com/en/watches/automat...   NaN  Jaquet Droz
# 104  https://www.jaquet-droz.com/en/watches/automat...   NaN  Jaquet Droz
# 105  https://www.jaquet-droz.com/en/watches/automat...   NaN  Jaquet Droz
# 122  https://www.jaquet-droz.com/en/watches/grande-...   NaN  Jaquet Droz
#
#      year_introduced    parent_model     specific_model  nickname  \
# ...

# %%
df[df['watch_URL'].isna()]
# Out:
#     field name                             reference_number watch_URL  type  \
# 131      value  Listed under "Technical Data" > "Reference"       NaN   NaN
#
#     brand  year_introduced                                parent_model  \
# 131   NaN              NaN  Product Breadcrumb on page or in watch_url
#
#                                         specific_model  nickname  \
# 131  Parent model + Product title (please make sure...       NaN
#
#      marketing_name  ...                        bracelet_material  \
# 131             NaN  ...  Listed under "Technical Data" > "Strap"
#
#                               bracelet_color  \
# 131  Listed under "Technical Data" > "Strap"
#
#                                      clasp_type  \
# 131  Listed under "Technical Data" > "Movement"
#
#                                         caliber  \
# 131  Listed under "Technical Data" > "Movement"
#
#                                        power_reserve  \
# ...

# %%
for i in df.columns:
    print(f'{i}: {df[i].isna().sum()}')
# Out:
# field name: 0
# reference_number: 0
# watch_URL: 1
# type: 132
# brand: 1
# year_introduced: 132
# parent_model: 0
# specific_model: 0
# nickname: 132
# marketing_name: 132
# style: 132
# currency: 132
# price: 132
# image_URL: 1
# made_in: 132
# case_shape: 132
# case_material: 0
# case_finish: 132
# caseback: 132
# diameter: 0
# between_lugs: 132
# lug_to_lug: 132
# case_thickness: 0
# bezel_material: 132
# bezel_color: 132
# crystal: 132
# water_resistance: 7
# weight: 132
# dial_color: 5
# numerals: 132
# bracelet_material: 5
# bracelet_color: 5
# clasp_type: 5
# caliber: 0
# power_reserve: 0
# frequency: 5
# jewels: 3
# features: 5
# description: 0
# short_description: 132
