# %%
import requests
from bs4 import BeautifulSoup, NavigableString
import pandas as pd
import re

# %%
def extract_asoup(url, parser='lxml'):
  page = requests.get(url)
  soup = BeautifulSoup(page.content, parser)
  return soup

# %%
watches_url = "https://www.jaquet-droz.com/en/watches"

# %%
soup = extract_asoup(watches_url, 'html.parser')

# %%
links = soup.find_all('a', href=True)
watches_urls = [link['href'] for link in links if link['href'].startswith("https://www.jaquet-droz.com/en/watches/")]
watches_urls
# Out:
# ['https://www.jaquet-droz.com/en/watches/timepieces',
#  'https://www.jaquet-droz.com/en/watches/automata',
#  'https://www.jaquet-droz.com/en/watches/ateliers-d-art',
#  'https://www.jaquet-droz.com/en/watches/grande-seconde',
#  'https://www.jaquet-droz.com/en/watches/sw',
#  'https://www.jaquet-droz.com/en/watches/petite-heure-minute',
#  'https://www.jaquet-droz.com/en/watches/lady-8',
#  'https://www.jaquet-droz.com/en/watches/astrale']

# %%
watches_data = []
for watch_url in watches_urls:
    watch_soup = extract_asoup(watch_url, 'html.parser')
    content = watch_soup.find('div', class_ = 'block block-system')
    if content is None:
        continue
    parent_model = content.find('h1').text
    item_list = content.find_all('a', href=True)
    urls =[link['href'] for link in item_list]
    for watch in urls:
        watch_URL = watch
        watch_infos = extract_asoup(watch, 'html.parser')
        watch_info = watch_infos.find('div', class_ = 'watch-infos')
        specific_model = watch_info.find('h1', class_ = 'title-node').text
        description = watch_info.find('div', class_ = 'description').text.strip()
        watch_spec = watch_info.find('div', class_ = 'watch-spec')
        features = watch_spec.find('th', text='Indications').find_next_sibling('td').text if watch_spec.find('th', text='Indications') else None
        jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text \
            if watch_spec.find('th', text='Jewelling') else None
        frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else None
        power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else None
        caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else None
        movement = caliber
        clasp_type = watch_spec.find('th', text='Buckle').find_next_sibling('td').text if watch_spec.find('th', text='Buckle') else None
        bracelet_color = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else None
        bracelet_material = bracelet_color
        dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else None
        water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text if watch_spec.find('th', text=lambda text: text and 'resistance' in text) else None
        case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else None
        diameter = case_thickness
        case_material = case_thickness

        image_URL = watch_infos.find('div', class_='watch-picture').find('img').get('src')
        price ="N/A"
        currency = "N/A"
        brand = "Jaquet Droz"
        reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text

        if watch_infos.select('div.variantes li.variante:not(.active)'):
            list_colors = [li.find('a')['href'] for li in watch_infos.select('div.variantes li.variante:not(.active)')]

            index = urls.index(watch)
            urls[index:index] = [item for item in list_colors if item not in urls]



        watches_data.append({
            "field name": "value",
            "reference_number": reference_number,
            "watch_URL": watch_URL,
            "type": '',
            "brand": brand,
            "year_introduced": '',
            "parent_model": parent_model,
            "specific_model": specific_model,
            "nickname": '',
            "marketing_name": '',
            "style": '',
            "currency": currency,
            "price": price,
            "image_URL": image_URL,
            "made_in": '',
            "case_shape": '',
            "case_material": case_material,
            "case_finish": '',
            "caseback": '',
            "diameter": diameter,
            "between_lugs": '',
            "lug_to_lug": '',
            "case_thickness": case_thickness,
            "bezel_material": '',
            "bezel_color": '',
            "crystal": '',
            "water_resistance": water_resistance,
            "weight": '',
            "dial_color": dial_color,
            "numerals": '',
            "bracelet_material": bracelet_material,
            "bracelet_color": bracelet_color,
            "clasp_type": clasp_type,
            "caliber": caliber,
           "power_reserve": power_reserve,
           "frequency": frequency,
           "jewels": jewels,
           "features": features,
           "description": description,
           "short_description": '',
        })
# Out:
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   features = watch_spec.find('th', text='Indications').find_next_sibling('td').text if watch_spec.find('th', text='Indications') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:19: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   if watch_spec.find('th', text='Jewelling') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:18: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text \
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:20: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:21: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:22: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:24: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   clasp_type = watch_spec.find('th', text='Buckle').find_next_sibling('td').text if watch_spec.find('th', text='Buckle') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:25: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   bracelet_color = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:27: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:28: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text if watch_spec.find('th', text=lambda text: text and 'resistance' in text) else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:29: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else None
# C:\Users\habob\AppData\Local\Temp\ipykernel_45044\606685296.py:37: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text

# %%
df_watches_data = pd.DataFrame(watches_data)
df_watches_data
# Out:
#     field name reference_number  \
# 0        value      J0328330011
# 1        value      J0328330011
# 2        value       J013523242
# 3        value       J013523242
# 4        value      J0135230011
# ..         ...              ...
# 126      value       J013013281
# 127      value       J013034240
# 128      value       J013013200
# 129      value       J013033200
# 130      value       J030033240
#
#                                              watch_URL type        brand  \
# 0    https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 1    https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 2    https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 3    https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 4    https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# ..                                                 ...  ...          ...
# 126  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 127  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 128  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 129  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 130  https://www.jaquet-droz.com/en/watches/sw/tour...       Jaquet Droz
#
#     year_introduced    parent_model                specific_model nickname  \
# 0                        Timepieces  The Rolling Stones Automaton
# 1                        Timepieces  The Rolling Stones Automaton
# 2                        Timepieces             Tourbillon Skelet
# 3                        Timepieces             Tourbillon Skelet
# 4                        Timepieces       Tourbillon Skelet Skull
# ..              ...             ...                           ...      ...
# 126                  GRANDE SECONDE            Tourbillon Jadeite
# 127                  GRANDE SECONDE    Tourbillon Côtes de Genève
# 128                  GRANDE SECONDE                    Tourbillon
# 129                  GRANDE SECONDE       Tourbillon Ivory Enamel
# 130                              SW                 Tourbillon SW
#
#     marketing_name  ...                                  bracelet_material  \
# 0                   ...             Fabric with printed patterns in rubber
# 1                   ...             Fabric with printed patterns in rubber
# 2                   ...              Rolled-edge hand-made black alligator
# 3                   ...              Rolled-edge hand-made black alligator
# 4                   ...                                       Rubber strap
# ..             ...  ...                                                ...
# 126                 ...                  Rolled-edge hand-made green satin
# 127                 ...  Rolled-edge hand-made black alligator leather ...
# 128                 ...  Rolled-edge hand-made black alligator leather ...
# 129                 ...  Rolled-edge hand-made black alligator leather ...
# 130                 ...  Rolled-edge hand made inserted black alligator...
#
#                                         bracelet_color  \
# 0               Fabric with printed patterns in rubber
# 1               Fabric with printed patterns in rubber
# 2                Rolled-edge hand-made black alligator
# 3                Rolled-edge hand-made black alligator
# 4                                         Rubber strap
# ..                                                 ...
# 126                  Rolled-edge hand-made green satin
# 127  Rolled-edge hand-made black alligator leather ...
# 128  Rolled-edge hand-made black alligator leather ...
# 129  Rolled-edge hand-made black alligator leather ...
# 130  Rolled-edge hand made inserted black alligator...
#
#                                             clasp_type  \
# 0                      18-karat red gold folding clasp
# 1                      18-karat red gold folding clasp
# 2                      18-karat red gold folding clasp
# 3                      18-karat red gold folding clasp
# 4                      18-karat red gold folding clasp
# ..                                                 ...
# 126  18-karat red gold folding clasp set with 32 di...
# 127                  18-carat white gold folding clasp
# 128                18-carat red gold folding clasp\r\n
# 129                    18-carat red gold folding clasp
# 130  18-carat red gold folding clasp with black PVD...
#
#                                                caliber power_reserve  \
# 0    Jaquet Droz 2653 AT2, self-winding mechanical ...      68 hours
# 1    Jaquet Droz 2653 AT2, self-winding mechanical ...      68 hours
# 2    Jaquet Droz 2625SQ, self-winding skeleton tour...        7 days
# 3    Jaquet Droz 2625SQ, self-winding skeleton tour...        7 days
# 4    Jaquet Droz 2625SQ, self-winding skeleton tour...        7 days
# ..                                                 ...           ...
# 126  Jaquet Droz 25JD, self-winding tourbillon move...        7 days
# 127  Jaquet Droz 25JD, self-winding tourbillon move...        7 days
# 128  Jaquet Droz 25JD, self-winding tourbillon move...        7 days
# 129  Jaquet Droz 25JD, self-winding tourbillon move...        7 days
# 130  Jaquet Droz 25JD-S, self-winding tourbillon mo...        7 days
#
#          frequency         jewels  \
# 0    28,800 v.p.h.      56 jewels
# 1    28,800 v.p.h.      56 jewels
# 2    21,600 v.p.h.      30 jewels
# 3    21,600 v.p.h.      30 jewels
# 4    21,600 v.p.h.      30 jewels
# ..             ...            ...
# 126  21,600 v.p.h.      31 jewels
# 127   21,600 v.p.h      31 jewels
# 128   21,600 v.p.h  31 jewels\r\n
# 129   21,600 v.p.h      31 jewels
# 130   21,600 v.p.h      31 jewels
#
#                                               features  \
# 0                       Off-centered hours and minutes
# 1                       Off-centered hours and minutes
# 2    Off-centered hours and minutes at 6 o'clock. T...
# 3    Off-centered hours and minutes at 6 o'clock. T...
# 4    Off-centered hours and minutes at 6 o'clock. T...
# ..                                                 ...
# 126  Hours and minutes at 6 o'clock Tourbillon fram...
# 127  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 128  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 129  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 130  Hours and minutes at 6 o'clock\r\nTourbillon f...
#
#                                            description short_description
# 0    Black onyx dial and 18-karat red gold applied ...
# 1    Black onyx dial and 18-karat red gold applied ...
# 2    Sapphire dial with metallic sapphire base. \r\...
# 3    Sapphire dial with metallic sapphire base. \r\...
# 4    Hand-engraved and hand-painted 18-karat gold d...
# ..                                                 ...               ...
# 126  Jadeite dial, white mother-of-pearl subdial. \...
# 127  Côtes de Genève technical dial,\r\nsapphire ri...
# 128  Ivory Grand Feu enamel, tourbillon frame. 18-c...
# 129  Ivory Grand Feu enameled dial.\r\n18-carat red...
# 130  Black dial with rubber treatment.\r\n18-carat ...
#
# [131 rows x 40 columns]

# %%
df_watches_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   field name         131 non-null    object
#  1   reference_number   131 non-null    object
#  2   watch_URL          131 non-null    object
#  3   type               131 non-null    object
#  4   brand              131 non-null    object
#  5   year_introduced    131 non-null    object
#  6   parent_model       131 non-null    object
#  7   specific_model     131 non-null    object
#  8   nickname           131 non-null    object
#  9   marketing_name     131 non-null    object
#  10  style              131 non-null    object
#  11  currency           131 non-null    object
#  12  price              131 non-null    object
#  13  image_URL          131 non-null    object
#  14  made_in            131 non-null    object
#  15  case_shape         131 non-null    object
#  16  case_material      131 non-null    object
#  17  case_finish        131 non-null    object
#  18  caseback           131 non-null    object
#  19  diameter           131 non-null    object
#  20  between_lugs       131 non-null    object
#  21  lug_to_lug         131 non-null    object
#  22  case_thickness     131 non-null    object
#  23  bezel_material     131 non-null    object
#  24  bezel_color        131 non-null    object
#  25  crystal            131 non-null    object
#  26  water_resistance   124 non-null    object
#  27  weight             131 non-null    object
#  28  dial_color         126 non-null    object
#  29  numerals           131 non-null    object
#  30  bracelet_material  126 non-null    object
#  31  bracelet_color     126 non-null    object
#  32  clasp_type         126 non-null    object
#  33  caliber            131 non-null    object
#  34  power_reserve      131 non-null    object
#  35  frequency          126 non-null    object
#  36  jewels             128 non-null    object
#  37  features           126 non-null    object
#  38  description        131 non-null    object
#  39  short_description  131 non-null    object
# dtypes: object(40)
# memory usage: 41.1+ KB

# %%
df_watches_data.isna().sum()
# Out:
# field name           0
# reference_number     0
# watch_URL            0
# type                 0
# brand                0
# year_introduced      0
# parent_model         0
# specific_model       0
# nickname             0
# marketing_name       0
# style                0
# currency             0
# price                0
# image_URL            0
# made_in              0
# case_shape           0
# case_material        0
# case_finish          0
# caseback             0
# diameter             0
# between_lugs         0
# lug_to_lug           0
# case_thickness       0
# bezel_material       0
# bezel_color          0
# crystal              0
# water_resistance     7
# weight               0
# dial_color           5
# numerals             0
# bracelet_material    5
# bracelet_color       5
# clasp_type           5
# caliber              0
# power_reserve        0
# frequency            5
# jewels               3
# features             5
# description          0
# short_description    0
# dtype: int64

# %%
df_watches_data.to_csv('df_watches_data.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd
df = pd.read_csv('df_watches_data.csv')
df
# Out:
#     field name reference_number  \
# 0        value      J0328330011
# 1        value      J0328330011
# 2        value       J013523242
# 3        value       J013523242
# 4        value      J0135230011
# ..         ...              ...
# 126      value       J013013281
# 127      value       J013034240
# 128      value       J013013200
# 129      value       J013033200
# 130      value       J030033240
#
#                                              watch_URL  type        brand  \
# 0    https://www.jaquet-droz.com/en/watches/automat...   NaN  Jaquet Droz
# 1    https://www.jaquet-droz.com/en/watches/automat...   NaN  Jaquet Droz
# 2    https://www.jaquet-droz.com/en/watches/grande-...   NaN  Jaquet Droz
# 3    https://www.jaquet-droz.com/en/watches/grande-...   NaN  Jaquet Droz
# 4    https://www.jaquet-droz.com/en/watches/grande-...   NaN  Jaquet Droz
# ..                                                 ...   ...          ...
# 126  https://www.jaquet-droz.com/en/watches/grande-...   NaN  Jaquet Droz
# 127  https://www.jaquet-droz.com/en/watches/grande-...   NaN  Jaquet Droz
# 128  https://www.jaquet-droz.com/en/watches/grande-...   NaN  Jaquet Droz
# 129  https://www.jaquet-droz.com/en/watches/grande-...   NaN  Jaquet Droz
# 130  https://www.jaquet-droz.com/en/watches/sw/tour...   NaN  Jaquet Droz
#
#      year_introduced    parent_model                specific_model  nickname  \
# 0                NaN      Timepieces  The Rolling Stones Automaton       NaN
# 1                NaN      Timepieces  The Rolling Stones Automaton       NaN
# 2                NaN      Timepieces             Tourbillon Skelet       NaN
# 3                NaN      Timepieces             Tourbillon Skelet       NaN
# 4                NaN      Timepieces       Tourbillon Skelet Skull       NaN
# ..               ...             ...                           ...       ...
# 126              NaN  GRANDE SECONDE            Tourbillon Jadeite       NaN
# 127              NaN  GRANDE SECONDE    Tourbillon Côtes de Genève       NaN
# 128              NaN  GRANDE SECONDE                    Tourbillon       NaN
# 129              NaN  GRANDE SECONDE       Tourbillon Ivory Enamel       NaN
# 130              NaN              SW                 Tourbillon SW       NaN
#
#      marketing_name  ...                                  bracelet_material  \
# 0               NaN  ...             Fabric with printed patterns in rubber
# 1               NaN  ...             Fabric with printed patterns in rubber
# 2               NaN  ...              Rolled-edge hand-made black alligator
# 3               NaN  ...              Rolled-edge hand-made black alligator
# 4               NaN  ...                                       Rubber strap
# ..              ...  ...                                                ...
# 126             NaN  ...                  Rolled-edge hand-made green satin
# 127             NaN  ...  Rolled-edge hand-made black alligator leather ...
# 128             NaN  ...  Rolled-edge hand-made black alligator leather ...
# 129             NaN  ...  Rolled-edge hand-made black alligator leather ...
# 130             NaN  ...  Rolled-edge hand made inserted black alligator...
#
#                                         bracelet_color  \
# 0               Fabric with printed patterns in rubber
# 1               Fabric with printed patterns in rubber
# 2                Rolled-edge hand-made black alligator
# 3                Rolled-edge hand-made black alligator
# 4                                         Rubber strap
# ..                                                 ...
# 126                  Rolled-edge hand-made green satin
# 127  Rolled-edge hand-made black alligator leather ...
# 128  Rolled-edge hand-made black alligator leather ...
# 129  Rolled-edge hand-made black alligator leather ...
# 130  Rolled-edge hand made inserted black alligator...
#
#                                             clasp_type  \
# 0                      18-karat red gold folding clasp
# 1                      18-karat red gold folding clasp
# 2                      18-karat red gold folding clasp
# 3                      18-karat red gold folding clasp
# 4                      18-karat red gold folding clasp
# ..                                                 ...
# 126  18-karat red gold folding clasp set with 32 di...
# 127                  18-carat white gold folding clasp
# 128                18-carat red gold folding clasp\r\n
# 129                    18-carat red gold folding clasp
# 130  18-carat red gold folding clasp with black PVD...
#
#                                                caliber  power_reserve  \
# 0    Jaquet Droz 2653 AT2, self-winding mechanical ...       68 hours
# 1    Jaquet Droz 2653 AT2, self-winding mechanical ...       68 hours
# 2    Jaquet Droz 2625SQ, self-winding skeleton tour...         7 days
# 3    Jaquet Droz 2625SQ, self-winding skeleton tour...         7 days
# 4    Jaquet Droz 2625SQ, self-winding skeleton tour...         7 days
# ..                                                 ...            ...
# 126  Jaquet Droz 25JD, self-winding tourbillon move...         7 days
# 127  Jaquet Droz 25JD, self-winding tourbillon move...         7 days
# 128  Jaquet Droz 25JD, self-winding tourbillon move...         7 days
# 129  Jaquet Droz 25JD, self-winding tourbillon move...         7 days
# 130  Jaquet Droz 25JD-S, self-winding tourbillon mo...         7 days
#
#          frequency         jewels  \
# 0    28,800 v.p.h.      56 jewels
# 1    28,800 v.p.h.      56 jewels
# 2    21,600 v.p.h.      30 jewels
# 3    21,600 v.p.h.      30 jewels
# 4    21,600 v.p.h.      30 jewels
# ..             ...            ...
# 126  21,600 v.p.h.      31 jewels
# 127   21,600 v.p.h      31 jewels
# 128   21,600 v.p.h  31 jewels\r\n
# 129   21,600 v.p.h      31 jewels
# 130   21,600 v.p.h      31 jewels
#
#                                               features  \
# 0                       Off-centered hours and minutes
# 1                       Off-centered hours and minutes
# 2    Off-centered hours and minutes at 6 o'clock. T...
# 3    Off-centered hours and minutes at 6 o'clock. T...
# 4    Off-centered hours and minutes at 6 o'clock. T...
# ..                                                 ...
# 126  Hours and minutes at 6 o'clock Tourbillon fram...
# 127  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 128  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 129  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 130  Hours and minutes at 6 o'clock\r\nTourbillon f...
#
#                                            description short_description
# 0    Black onyx dial and 18-karat red gold applied ...               NaN
# 1    Black onyx dial and 18-karat red gold applied ...               NaN
# 2    Sapphire dial with metallic sapphire base. \r\...               NaN
# 3    Sapphire dial with metallic sapphire base. \r\...               NaN
# 4    Hand-engraved and hand-painted 18-karat gold d...               NaN
# ..                                                 ...               ...
# 126  Jadeite dial, white mother-of-pearl subdial. \...               NaN
# 127  Côtes de Genève technical dial,\r\nsapphire ri...               NaN
# 128  Ivory Grand Feu enamel, tourbillon frame. 18-c...               NaN
# 129  Ivory Grand Feu enameled dial.\r\n18-carat red...               NaN
# 130  Black dial with rubber treatment.\r\n18-carat ...               NaN
#
# [131 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   field name         131 non-null    object
#  1   reference_number   131 non-null    object
#  2   watch_URL          131 non-null    object
#  3   type               0 non-null      float64
#  4   brand              131 non-null    object
#  5   year_introduced    0 non-null      float64
#  6   parent_model       131 non-null    object
#  7   specific_model     131 non-null    object
#  8   nickname           0 non-null      float64
#  9   marketing_name     0 non-null      float64
#  10  style              0 non-null      float64
#  11  currency           0 non-null      float64
#  12  price              0 non-null      float64
#  13  image_URL          131 non-null    object
#  14  made_in            0 non-null      float64
#  15  case_shape         0 non-null      float64
#  16  case_material      131 non-null    object
#  17  case_finish        0 non-null      float64
#  18  caseback           0 non-null      float64
#  19  diameter           131 non-null    object
#  20  between_lugs       0 non-null      float64
#  21  lug_to_lug         0 non-null      float64
#  22  case_thickness     131 non-null    object
#  23  bezel_material     0 non-null      float64
#  24  bezel_color        0 non-null      float64
#  25  crystal            0 non-null      float64
#  26  water_resistance   124 non-null    object
#  27  weight             0 non-null      float64
#  28  dial_color         126 non-null    object
#  29  numerals           0 non-null      float64
#  30  bracelet_material  126 non-null    object
#  31  bracelet_color     126 non-null    object
#  32  clasp_type         126 non-null    object
#  33  caliber            131 non-null    object
#  34  power_reserve      131 non-null    object
#  35  frequency          126 non-null    object
#  36  jewels             128 non-null    object
#  37  features           126 non-null    object
#  38  description        131 non-null    object
#  39  short_description  0 non-null      float64
# dtypes: float64(19), object(21)
# memory usage: 41.1+ KB

# %%
df.isna().sum()
# Out:
# field name             0
# reference_number       0
# watch_URL              0
# type                 131
# brand                  0
# year_introduced      131
# parent_model           0
# specific_model         0
# nickname             131
# marketing_name       131
# style                131
# currency             131
# price                131
# image_URL              0
# made_in              131
# case_shape           131
# case_material          0
# case_finish          131
# caseback             131
# diameter               0
# between_lugs         131
# lug_to_lug           131
# case_thickness         0
# bezel_material       131
# bezel_color          131
# crystal              131
# water_resistance       7
# weight               131
# dial_color             5
# numerals             131
# bracelet_material      5
# bracelet_color         5
# clasp_type             5
# caliber                0
# power_reserve          0
# frequency              5
# jewels                 3
# features               5
# description            0
# short_description    131
# dtype: int64
