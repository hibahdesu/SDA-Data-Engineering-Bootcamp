# %%
import requests
from bs4 import BeautifulSoup, NavigableString
import pandas as pd
import re

# %%
def extract_asoup(url, parser='lxml'):
  page = requests.get(url)
  soup = BeautifulSoup(page.content, parser)
  return soup

# %%
watches_url = "https://www.jaquet-droz.com/en/watches"

# %%
soup = extract_asoup(watches_url, 'html.parser')

# %%
import requests
from bs4 import BeautifulSoup, NavigableString
import pandas as pd
import re


def extract_asoup(url, parser='lxml'):
  page = requests.get(url)
  soup = BeautifulSoup(page.content, parser)
  return soup


watches_url = "https://www.jaquet-droz.com/en/watches"


soup = extract_asoup(watches_url, 'html.parser')
links = soup.find_all('a', href=True)
watches_urls = [link['href'] for link in links if link['href'].startswith("https://www.jaquet-droz.com/en/watches/")]
watches_urls

watches_data = []
for watch_url in watches_urls:
    watch_soup = extract_asoup(watch_url, 'html.parser')
    content = watch_soup.find('div', class_ = 'block block-system')
    if content is None:
        continue
    parent_model = content.find('h1').text
    item_list = content.find_all('a', href=True)
    urls =[link['href'] for link in item_list]
    for watch in urls:
        watch_URL = watch
        watch_infos = extract_asoup(watch, 'html.parser')
        watch_info = watch_infos.find('div', class_ = 'watch-infos')
        specific_model = watch_info.find('h1', class_ = 'title-node').text
        description = watch_info.find('div', class_ = 'description').text.strip()
        watch_spec = watch_info.find('div', class_ = 'watch-spec')
        features = watch_spec.find('th', text='Indications').find_next_sibling('td').text if watch_spec.find('th', text='Indications') else "None"
        jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text \
            if watch_spec.find('th', text='Jewelling') else ""
        frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else ""
        power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else ""
        caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else ""
        movement = caliber
        clasp_type = watch_spec.find('th', text='Buckle').find_next_sibling('td').text if watch_spec.find('th', text='Buckle') else ""
        bracelet_color = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else ""
        bracelet_material = bracelet_color
        dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else ""
        water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text 
                            if watch_spec.find('th', text=lambda text: text and 'resistance' in text) 
                            else ""
        case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else ""
        diameter = case_thickness
        case_material = case_thickness

        image_URL = watch_infos.find('div', class_='watch-picture').find('img').get('src')
        price ="N/A"
        currency = "N/A"
        brand = "Jaquet Droz"
        reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text
        watches_data.append({
            "field name": "value",
            "reference_number": reference_number,
            "watch_URL": watch_URL,
            "type": "",
            "brand": brand,
            "year_introduced": "",
            "parent_model": parent_model,
            "specific_model": specific_model,
            "nickname": "",
            "marketing_name": "",
            "style": "",
            "currency": currency,
            "price": price,
            "image_URL": image_URL,
            "made_in": "",
            "case_shape": "",
            "case_material": case_material,
            "case_finish": "",
            "caseback": "",
            "diameter": diameter,
            "between_lugs": "",
            "lug_to_lug": "",
            "case_thickness": case_thickness,
            "bezel_material": "",
            "bezel_color": "",
            "crystal": "",
            "water_resistance": water_resistance,
            "weight": "",
            "dial_color": dial_color,
            "numerals": "",
            "bracelet_material": bracelet_material,
            "bracelet_color": bracelet_color,
            "clasp_type": clasp_type,
            "caliber": caliber,
           "power_reserve": power_reserve,
           "frequency": frequency,
           "jewels": jewels,
           "features": features,
           "description": description,
           "short_description": "",
        })
# Out:
# ['https://www.jaquet-droz.com/en/watches/timepieces',
#  'https://www.jaquet-droz.com/en/watches/automata',
#  'https://www.jaquet-droz.com/en/watches/ateliers-d-art',
#  'https://www.jaquet-droz.com/en/watches/grande-seconde',
#  'https://www.jaquet-droz.com/en/watches/sw',
#  'https://www.jaquet-droz.com/en/watches/petite-heure-minute',
#  'https://www.jaquet-droz.com/en/watches/lady-8',
#  'https://www.jaquet-droz.com/en/watches/astrale']

# %%
watches_data = []
for watch_url in watches_urls:
    watch_soup = extract_asoup(watch_url, 'html.parser')
    content = watch_soup.find('div', class_ = 'block block-system')
    if content is None:
        continue
    parent_model = content.find('h1').text
    item_list = content.find_all('a', href=True)
    urls =[link['href'] for link in item_list]
    for watch in urls:
        watch_URL = watch
        watch_infos = extract_asoup(watch, 'html.parser')
        watch_info = watch_infos.find('div', class_ = 'watch-infos')
        specific_model = watch_info.find('h1', class_ = 'title-node').text
        description = watch_info.find('div', class_ = 'description').text.strip()
        watch_spec = watch_info.find('div', class_ = 'watch-spec')
        features = watch_spec.find('th', text='Indications').find_next_sibling('td').text if watch_spec.find('th', text='Indications') else "None"
        jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text \
            if watch_spec.find('th', text='Jewelling') else ""
        frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else ""
        power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else ""
        caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else ""
        movement = caliber
        clasp_type = watch_spec.find('th', text='Buckle').find_next_sibling('td').text if watch_spec.find('th', text='Buckle') else ""
        bracelet_color = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else ""
        bracelet_material = bracelet_color
        dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else ""
        water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text if watch_spec.find('th', text=lambda text: text and 'resistance' in text) else ""
        case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else ""
        diameter = case_thickness
        case_material = case_thickness

        image_URL = watch_infos.find('div', class_='watch-picture').find('img').get('src')
        price ="N/A"
        currency = "N/A"
        brand = "Jaquet Droz"
        reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text
        watches_data.append({
            "field name": "value",
            "reference_number": reference_number,
            "watch_URL": watch_URL,
            "type": "",
            "brand": brand,
            "year_introduced": "",
            "parent_model": parent_model,
            "specific_model": specific_model,
            "nickname": "",
            "marketing_name": "",
            "style": "",
            "currency": currency,
            "price": price,
            "image_URL": image_URL,
            "made_in": "",
            "case_shape": "",
            "case_material": case_material,
            "case_finish": "",
            "caseback": "",
            "diameter": diameter,
            "between_lugs": "",
            "lug_to_lug": "",
            "case_thickness": case_thickness,
            "bezel_material": "",
            "bezel_color": "",
            "crystal": "",
            "water_resistance": water_resistance,
            "weight": "",
            "dial_color": dial_color,
            "numerals": "",
            "bracelet_material": bracelet_material,
            "bracelet_color": bracelet_color,
            "clasp_type": clasp_type,
            "caliber": caliber,
           "power_reserve": power_reserve,
           "frequency": frequency,
           "jewels": jewels,
           "features": features,
           "description": description,
           "short_description": "",
        })
        
        
watches_data.append({
            "field name": "value",
            "reference_number": "Listed under \"Technical Data\" > \"Reference\"",
            "watch_URL": "",
            "type": "",
            "brand": "",
            "year_introduced": "",
            "parent_model": "Product Breadcrumb on page or in watch_url",
            "specific_model": "Parent model + Product title (please make sure to scrape the actual html text so the capitalization is correct)",
            "nickname": "",
            "marketing_name": "",
            "style": "",
            "currency": "N/A",
            "price": "N/A",
            "image_URL": "",
            "made_in": "",
            "case_shape": "",
            "case_material": "Listed under \"Technical Data\" > \"Case\"",
            "case_finish": "",
            "caseback": "",
            "diameter": "Listed under \"Technical Data\" > \"Case\". If you can extract just the Diameter sentence that's great, but if not, just do the whole field.",
            "between_lugs": "",
            "lug_to_lug": "",
            "case_thickness": "Listed under \"Technical Data\" > \"Case\". If you can extract just the Diameter sentence that's great, but if not, just do the whole field.",
            "bezel_material": "",
            "bezel_color": "",
            "crystal": "",
            "water_resistance": "Listed under \"Technical Data\" > \"Water Resistance\"",
            "weight": "",
            "dial_color": "Listed under \"Technical Data\" > \"Dial\"",
            "numerals": "",
            "bracelet_material": "Listed under \"Technical Data\" > \"Strap\"",
            "bracelet_color": "Listed under \"Technical Data\" > \"Strap\"",
            "clasp_type": "Listed under \"Technical Data\" > \"Movement\"",
            "caliber": "Listed under \"Technical Data\" > \"Movement\"",
           "power_reserve": "Listed under \"Technical Data\" > \"Power Reserve\"",
           "frequency": "Listed under \"Technical Data\" > \"Frequency\"",
           "jewels": "Listed under \"Technical Data\" > \"Jewelling\"",
           "features": "Listed under \"Technical Data\" > \"Indications\"",
           "description": "Main product description (before you click Technical Data)",
           "short_description": "",
        })


df_watches_data = pd.DataFrame(watches_data)
df_watches_data
# Out:
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   features = watch_spec.find('th', text='Indications').find_next_sibling('td').text if watch_spec.find('th', text='Indications') else "None"
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:19: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   if watch_spec.find('th', text='Jewelling') else ""
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:18: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   jewels = watch_spec.find('th', text='Jewelling').find_next_sibling('td').text \
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:20: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   frequency = watch_spec.find('th', text='Frequency').find_next_sibling('td').text if watch_spec.find('th', text='Frequency') else ""
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:21: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   power_reserve = watch_spec.find('th', text='Power reserve').find_next_sibling('td').text if watch_spec.find('th', text='Power reserve') else ""
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:22: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   caliber = watch_spec.find('th', text='Movement').find_next_sibling('td').text if watch_spec.find('th', text='Movement') else ""
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:24: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   clasp_type = watch_spec.find('th', text='Buckle').find_next_sibling('td').text if watch_spec.find('th', text='Buckle') else ""
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:25: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   bracelet_color = watch_spec.find('th', text='Strap').find_next_sibling('td').text if watch_spec.find('th', text='Strap') else ""
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:27: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   dial_color = watch_spec.find('th', text='Dial').find_next_sibling('td').text if watch_spec.find('th', text='Dial') else ""
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:28: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   water_resistance = watch_spec.find('th', text=lambda text: text and 'resistance' in text).find_next_sibling('td').text if watch_spec.find('th', text=lambda text: text and 'resistance' in text) else ""
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:29: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   case_thickness = watch_spec.find('th', text='Case').find_next_sibling('td').text if watch_spec.find('th', text='Case') else ""
# C:\Users\habob\AppData\Local\Temp\ipykernel_38564\2632527657.py:37: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   reference_number = watch_spec.find('th', text='Reference').find_next_sibling('td').text

# %%
watches_data.append({
            "field name": "value",
            "reference_number": "Listed under \"Technical Data\" > \"Reference\"",
            "watch_URL": "",
            "type": "",
            "brand": "",
            "year_introduced": "",
            "parent_model": "Product Breadcrumb on page or in watch_url",
            "specific_model": "Parent model + Product title (please make sure to scrape the actual html text so the capitalization is correct)",
            "nickname": "",
            "marketing_name": "",
            "style": "",
            "currency": "N/A",
            "price": "N/A",
            "image_URL": "",
            "made_in": "",
            "case_shape": "",
            "case_material": "Listed under \"Technical Data\" > \"Case\"",
            "case_finish": "",
            "caseback": "",
            "diameter": "Listed under \"Technical Data\" > \"Case\". If you can extract just the Diameter sentence that's great, but if not, just do the whole field.",
            "between_lugs": "",
            "lug_to_lug": "",
            "case_thickness": "Listed under \"Technical Data\" > \"Case\". If you can extract just the Diameter sentence that's great, but if not, just do the whole field.",
            "bezel_material": "",
            "bezel_color": "",
            "crystal": "",
            "water_resistance": "Listed under \"Technical Data\" > \"Water Resistance\"",
            "weight": "",
            "dial_color": "Listed under \"Technical Data\" > \"Dial\"",
            "numerals": "",
            "bracelet_material": "Listed under \"Technical Data\" > \"Strap\"",
            "bracelet_color": "Listed under \"Technical Data\" > \"Strap\"",
            "clasp_type": "Listed under \"Technical Data\" > \"Movement\"",
            "caliber": "Listed under \"Technical Data\" > \"Movement\"",
           "power_reserve": "Listed under \"Technical Data\" > \"Power Reserve\"",
           "frequency": "Listed under \"Technical Data\" > \"Frequency\"",
           "jewels": "Listed under \"Technical Data\" > \"Jewelling\"",
           "features": "Listed under \"Technical Data\" > \"Indications\"",
           "description": "Main product description (before you click Technical Data)",
           "short_description": "",
        })

# %%
df_watches_data = pd.DataFrame(watches_data)
df_watches_data
# Out:
#    field name                             reference_number  \
# 0       value                                  J0328330011
# 1       value                                   J013523242
# 2       value                                  J0135230011
# 3       value                                  J0135250061
# 4       value                                  J0135270021
# 5       value                                  J0327370011
# 6       value                                   J031033211
# 7       value                                   J031534240
# 8       value                                   J032533275
# 9       value                                   J032633270
# 10      value                                   J033033202
# 11      value                                   J032004201
# 12      value                                   J005024288
# 13      value                                   J013033243
# 14      value                                   J011033202
# 15      value                                   J013013200
# 16      value                                   J030033240
# 17      value                                 J899.000.064
# 18      value                                 J899.000.070
# 19      value                                 J899.000.052
# 20      value                                  J0328330011
# 21      value                                   J031034205
# 22      value                                  J0327370011
# 23      value                                   J031534240
# 24      value                                   J032533275
# 25      value                                   J032633270
# 26      value                                   J033033202
# 27      value                                   J032003200
# 28      value                                 J899.000.064
# 29      value                                 J899.000.070
# 30      value                                   J013033243
# 31      value                                   J013523242
# 32      value                                  J0135230011
# 33      value                                  J0135250061
# 34      value                                  J0135270021
# 35      value                                   J011033202
# 36      value                                   J013033200
# 37      value                                   J030033240
# 38      value  Listed under "Technical Data" > "Reference"
#
#                                             watch_URL type        brand  \
# 0   https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 1   https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 2   https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 3   https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 4   https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 5   https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 6   https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 7   https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 8   https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 9   https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 10  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 11  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 12  https://www.jaquet-droz.com/en/watches/atelier...       Jaquet Droz
# 13  https://www.jaquet-droz.com/en/watches/atelier...       Jaquet Droz
# 14  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 15  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 16  https://www.jaquet-droz.com/en/watches/sw/tour...       Jaquet Droz
# 17  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 18  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 19  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 20  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 21  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 22  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 23  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 24  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 25  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 26  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 27  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 28  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 29  https://www.jaquet-droz.com/en/watches/automat...       Jaquet Droz
# 30  https://www.jaquet-droz.com/en/watches/atelier...       Jaquet Droz
# 31  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 32  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 33  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 34  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 35  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 36  https://www.jaquet-droz.com/en/watches/grande-...       Jaquet Droz
# 37  https://www.jaquet-droz.com/en/watches/sw/tour...       Jaquet Droz
# 38
#
#    year_introduced                                parent_model  \
# 0                                                   Timepieces
# 1                                                   Timepieces
# 2                                                   Timepieces
# 3                                                   Timepieces
# 4                                                   Timepieces
# 5                                                   Timepieces
# 6                                                   Timepieces
# 7                                                   Timepieces
# 8                                                   Timepieces
# 9                                                   Timepieces
# 10                                                  Timepieces
# 11                                                  Timepieces
# 12                                                  Timepieces
# 13                                                  Timepieces
# 14                                                  Timepieces
# 15                                                  Timepieces
# 16                                                  Timepieces
# 17                                                  Timepieces
# 18                                                  Timepieces
# 19                                                  Timepieces
# 20                                                    AUTOMATA
# 21                                                    AUTOMATA
# 22                                                    AUTOMATA
# 23                                                    AUTOMATA
# 24                                                    AUTOMATA
# 25                                                    AUTOMATA
# 26                                                    AUTOMATA
# 27                                                    AUTOMATA
# 28                                                    AUTOMATA
# 29                                                    AUTOMATA
# 30                                              ATELIERS D'ART
# 31                                              GRANDE SECONDE
# 32                                              GRANDE SECONDE
# 33                                              GRANDE SECONDE
# 34                                              GRANDE SECONDE
# 35                                              GRANDE SECONDE
# 36                                              GRANDE SECONDE
# 37                                                          SW
# 38                  Product Breadcrumb on page or in watch_url
#
#                                        specific_model nickname marketing_name  \
# 0                        The Rolling Stones Automaton
# 1                                   Tourbillon Skelet
# 2                             Tourbillon Skelet Skull
# 3                           Tourbillon Skelet Ceramic
# 4                          Tourbillon Skelet Sapphire
# 5                                    Dragon Automaton
# 6                                       Bird Repeater
# 7                                       Charming Bird
# 8                                    Loving Butterfly
# 9                                         Magic Lotus
# 10                             Tropical Bird Repeater
# 11                                      Lady 8 Flower
# 12                                       Relief Tiger
# 13                              Tourbillon Paillonnée
# 14                                    Minute Repeater
# 15                                         Tourbillon
# 16                                      Tourbillon SW
# 17                                    Signing Machine
# 18                                  Whistling Machine
# 19                                           The Poet
# 20                       The Rolling Stones Automaton
# 21                          Bird Repeater Alpine View
# 22                                   Dragon Automaton
# 23                                      Charming Bird
# 24                                   Loving Butterfly
# 25                                        Magic Lotus
# 26                             Tropical Bird Repeater
# 27                                      Lady 8 Flower
# 28                                    Signing Machine
# 29                                  Whistling Machine
# 30                              Tourbillon Paillonnée
# 31                                  Tourbillon Skelet
# 32                            Tourbillon Skelet Skull
# 33                          Tourbillon Skelet Ceramic
# 34                         Tourbillon Skelet Sapphire
# 35                                    Minute Repeater
# 36                            Tourbillon Ivory Enamel
# 37                                      Tourbillon SW
# 38  Parent model + Product title (please make sure...
#
#     ...                                  bracelet_material  \
# 0   ...             Fabric with printed patterns in rubber
# 1   ...              Rolled-edge hand-made black alligator
# 2   ...                                       Rubber strap
# 3   ...                                       Rubber strap
# 4   ...                                    Alligator strap
# 5   ...                                       Rubber strap
# 6   ...  Rolled-edge hand-made black alligator strap wi...
# 7   ...   Rolled-edge hand-made black alligator leather...
# 8   ...              Rolled-edge hand-made black alligator
# 9   ...         Rolled-edge hand-made dark green alligator
# 10  ...              Rolled-edge hand-made brown alligator
# 11  ...          Rolled-edge hand-made dark-blue alligator
# 12  ...              Rolled-edge hand-made black alligator
# 13  ...        Rolled-edge hand-made black alligator strap
# 14  ...  Rolled-edge hand-made black alligator leather ...
# 15  ...  Rolled-edge hand-made black alligator leather ...
# 16  ...  Rolled-edge hand made inserted black alligator...
# 17  ...
# 18  ...
# 19  ...
# 20  ...             Fabric with printed patterns in rubber
# 21  ...  Rolled-edge hand-made black alligator leather ...
# 22  ...                                       Rubber strap
# 23  ...   Rolled-edge hand-made black alligator leather...
# 24  ...              Rolled-edge hand-made black alligator
# 25  ...         Rolled-edge hand-made dark green alligator
# 26  ...              Rolled-edge hand-made brown alligator
# 27  ...  Rolled-edge hand-made brown alligator leather\r\n
# 28  ...
# 29  ...
# 30  ...        Rolled-edge hand-made black alligator strap
# 31  ...              Rolled-edge hand-made black alligator
# 32  ...                                       Rubber strap
# 33  ...                                       Rubber strap
# 34  ...                                    Alligator strap
# 35  ...  Rolled-edge hand-made black alligator leather ...
# 36  ...  Rolled-edge hand-made black alligator leather ...
# 37  ...  Rolled-edge hand made inserted black alligator...
# 38  ...            Listed under "Technical Data" > "Strap"
#
#                                        bracelet_color  \
# 0              Fabric with printed patterns in rubber
# 1               Rolled-edge hand-made black alligator
# 2                                        Rubber strap
# 3                                        Rubber strap
# 4                                     Alligator strap
# 5                                        Rubber strap
# 6   Rolled-edge hand-made black alligator strap wi...
# 7    Rolled-edge hand-made black alligator leather...
# 8               Rolled-edge hand-made black alligator
# 9          Rolled-edge hand-made dark green alligator
# 10              Rolled-edge hand-made brown alligator
# 11          Rolled-edge hand-made dark-blue alligator
# 12              Rolled-edge hand-made black alligator
# 13        Rolled-edge hand-made black alligator strap
# 14  Rolled-edge hand-made black alligator leather ...
# 15  Rolled-edge hand-made black alligator leather ...
# 16  Rolled-edge hand made inserted black alligator...
# 17
# 18
# 19
# 20             Fabric with printed patterns in rubber
# 21  Rolled-edge hand-made black alligator leather ...
# 22                                       Rubber strap
# 23   Rolled-edge hand-made black alligator leather...
# 24              Rolled-edge hand-made black alligator
# 25         Rolled-edge hand-made dark green alligator
# 26              Rolled-edge hand-made brown alligator
# 27  Rolled-edge hand-made brown alligator leather\r\n
# 28
# 29
# 30        Rolled-edge hand-made black alligator strap
# 31              Rolled-edge hand-made black alligator
# 32                                       Rubber strap
# 33                                       Rubber strap
# 34                                    Alligator strap
# 35  Rolled-edge hand-made black alligator leather ...
# 36  Rolled-edge hand-made black alligator leather ...
# 37  Rolled-edge hand made inserted black alligator...
# 38            Listed under "Technical Data" > "Strap"
#
#                                            clasp_type  \
# 0                     18-karat red gold folding clasp
# 1                     18-karat red gold folding clasp
# 2                     18-karat red gold folding clasp
# 3          Ceramic folding clasp with black treatment
# 4    Stainless steel and plasma ceramic folding clasp
# 5           Stainless steel and ceramic folding clasp
# 6           Luxury folding clasp in 18-karat red gold
# 7   18-carat white gold prestige folding clasp\r\n...
# 8                     18-karat red gold folding clasp
# 9                     18-karat red gold folding clasp
# 10          Luxury folding clasp in 18-karat red gold
# 11  18-karat white gold folding clasp set with 47 ...
# 12                18-karat white gold ardillon buckle
# 13                    18-karat red gold folding clasp
# 14                    18-carat red gold folding clasp
# 15                18-carat red gold folding clasp\r\n
# 16  18-carat red gold folding clasp with black PVD...
# 17
# 18
# 19
# 20                    18-karat red gold folding clasp
# 21                  18-carat white gold folding clasp
# 22          Stainless steel and ceramic folding clasp
# 23  18-carat white gold prestige folding clasp\r\n...
# 24                    18-karat red gold folding clasp
# 25                    18-karat red gold folding clasp
# 26          Luxury folding clasp in 18-karat red gold
# 27  18-carat red gold folding clasp set with 21 di...
# 28
# 29
# 30                    18-karat red gold folding clasp
# 31                    18-karat red gold folding clasp
# 32                    18-karat red gold folding clasp
# 33         Ceramic folding clasp with black treatment
# 34   Stainless steel and plasma ceramic folding clasp
# 35                    18-carat red gold folding clasp
# 36                    18-carat red gold folding clasp
# 37  18-carat red gold folding clasp with black PVD...
# 38         Listed under "Technical Data" > "Movement"
#
#                                               caliber  \
# 0   Jaquet Droz 2653 AT2, self-winding mechanical ...
# 1   Jaquet Droz 2625SQ, self-winding skeleton tour...
# 2   Jaquet Droz 2625SQ, self-winding skeleton tour...
# 3   Jaquet Droz 2625SQ, self-winding skeleton tour...
# 4   Jaquet Droz 2625SQ, self-winding skeleton tour...
# 5   Jaquet Droz 6150, self-winding mechanical move...
# 6   Jaquet Droz RMA88, minute repeater, hand-windi...
# 7   Jaquet Droz 615, self-winding mechanical movem...
# 8   Jaquet Droz 2653 AT1, self-winding mechanical ...
# 9   Jaquet Droz 2653 AT2, self-winding mechanical ...
# 10  Jaquet Droz RMA89, minute repeater hand-windin...
# 11  Mechanical opening flower automaton movement. ...
# 12  Jaquet Droz 2653.Si, self-winding mechanical m...
# 13  Jaquet Droz 25JD.Si, self-winding tourbillon m...
# 14  Jaquet Droz 2635, minute repeater self-winding...
# 15  Jaquet Droz 25JD, self-winding tourbillon move...
# 16  Jaquet Droz 25JD-S, self-winding tourbillon mo...
# 17  JAQUET DROZ MAS, mechanical movement hand-woun...
# 18  JAQUET DROZ MASIF, hand-wound automaton moveme...
# 19   JAQUET DROZ, hand-winding movement, painted bird
# 20  Jaquet Droz 2653 AT2, self-winding mechanical ...
# 21  Jaquet Droz RMA88, minute repeater hand-windin...
# 22  Jaquet Droz 6150, self-winding mechanical move...
# 23  Jaquet Droz 615, self-winding mechanical movem...
# 24  Jaquet Droz 2653 AT1, self-winding mechanical ...
# 25  Jaquet Droz 2653 AT2, self-winding mechanical ...
# 26  Jaquet Droz RMA89, minute repeater hand-windin...
# 27  Jaquet Droz 615, self-winding mechanical movem...
# 28  JAQUET DROZ MAS, mechanical movement hand-woun...
# 29  JAQUET DROZ MASIF, hand-wound automaton moveme...
# 30  Jaquet Droz 25JD.Si, self-winding tourbillon m...
# 31  Jaquet Droz 2625SQ, self-winding skeleton tour...
# 32  Jaquet Droz 2625SQ, self-winding skeleton tour...
# 33  Jaquet Droz 2625SQ, self-winding skeleton tour...
# 34  Jaquet Droz 2625SQ, self-winding skeleton tour...
# 35  Jaquet Droz 2635, minute repeater self-winding...
# 36  Jaquet Droz 25JD, self-winding tourbillon move...
# 37  Jaquet Droz 25JD-S, self-winding tourbillon mo...
# 38         Listed under "Technical Data" > "Movement"
#
#                                       power_reserve  \
# 0                                          68 hours
# 1                                            7 days
# 2                                            7 days
# 3                                            7 days
# 4                                            7 days
# 5                                          38 hours
# 6                                          48 hours
# 7                                          38 hours
# 8                                          68 hours
# 9                                          68 hours
# 10                                         50 hours
# 11                                         38 hours
# 12                                         68 hours
# 13                                           7 days
# 14                                         40 hours
# 15                                           7 days
# 16                                           7 days
# 17                                     2 signatures
# 18                                        2 minutes
# 19                                        2 minutes
# 20                                         68 hours
# 21                                         48 hours
# 22                                         38 hours
# 23                                         38 hours
# 24                                         68 hours
# 25                                         68 hours
# 26                                         50 hours
# 27                                         38 hours
# 28                                     2 signatures
# 29                                        2 minutes
# 30                                           7 days
# 31                                           7 days
# 32                                           7 days
# 33                                           7 days
# 34                                           7 days
# 35                                         40 hours
# 36                                           7 days
# 37                                           7 days
# 38  Listed under "Technical Data" > "Power Reserve"
#
#                                       frequency  \
# 0                                 28,800 v.p.h.
# 1                                 21,600 v.p.h.
# 2                                 21,600 v.p.h.
# 3                                 21,600 v.p.h.
# 4                                 21,600 v.p.h.
# 5                                 21,600 v.p.h.
# 6                                  18,000 v.p.h
# 7                                  21,600 v.p.h
# 8                                 28,800 v.p.h.
# 9                                 28,800 v.p.h.
# 10                                 21,600 v.p.h
# 11                                21,600 v.p.h.
# 12                                28,800 v.p.h.
# 13                                21,600 v.p.h.
# 14                                 21,600 v.p.h
# 15                                 21,600 v.p.h
# 16                                 21,600 v.p.h
# 17
# 18
# 19
# 20                                28,800 v.p.h.
# 21                                18,000 v.p.h.
# 22                                21,600 v.p.h.
# 23                                 21,600 v.p.h
# 24                                28,800 v.p.h.
# 25                                28,800 v.p.h.
# 26                                 21,600 v.p.h
# 27                                21,600 v.p.h.
# 28
# 29
# 30                                21,600 v.p.h.
# 31                                21,600 v.p.h.
# 32                                21,600 v.p.h.
# 33                                21,600 v.p.h.
# 34                                21,600 v.p.h.
# 35                                 21,600 v.p.h
# 36                                 21,600 v.p.h
# 37                                 21,600 v.p.h
# 38  Listed under "Technical Data" > "Frequency"
#
#                                                jewels  \
# 0                                           56 jewels
# 1                                           30 jewels
# 2                                           30 jewels
# 3                                           30 jewels
# 4                                           30 jewels
# 5   78 jewels for the automaton movement + 29 jewe...
# 6                                           69 jewels
# 7                                   29 jewels\r\n\r\n
# 8                                           57 jewels
# 9                                           56 jewels
# 10                                          86 jewels
# 11        Movement 29 jewels, and automaton 24 jewels
# 12                                          28 jewels
# 13                                          31 jewels
# 14                                          39 jewels
# 15                                      31 jewels\r\n
# 16                                          31 jewels
# 17                                           8 jewels
# 18
# 19
# 20                                          56 jewels
# 21                                          69 jewels
# 22  78 jewels for the automaton movement + 29 jewe...
# 23                                  29 jewels\r\n\r\n
# 24                                          57 jewels
# 25                                          56 jewels
# 26                                          86 jewels
# 27                                      29 jewels\r\n
# 28                                           8 jewels
# 29
# 30                                          31 jewels
# 31                                          30 jewels
# 32                                          30 jewels
# 33                                          30 jewels
# 34                                          30 jewels
# 35                                          39 jewels
# 36                                          31 jewels
# 37                                          31 jewels
# 38        Listed under "Technical Data" > "Jewelling"
#
#                                              features  \
# 0                      Off-centered hours and minutes
# 1   Off-centered hours and minutes at 6 o'clock. T...
# 2   Off-centered hours and minutes at 6 o'clock. T...
# 3   Off-centered hours and minutes at 6 o'clock. T...
# 4   Off-centered hours and minutes at 6 o'clock. T...
# 5                      Off-centered hours and minutes
# 6                      Off-centered hours and minutes
# 7   Singing bird action\r\n15 jewels\r\nOff-center...
# 8        Off-centered hours and minutes at 12 o'clock
# 9                      Off-centered hours and minutes
# 10                     Off-centered hours and minutes
# 11                         Centered hours and minutes
# 12                     Off-centered hours and minutes
# 13  Off-centered hours and minutes Off-centered to...
# 14  Off-centered hours and minutes, large seconds ...
# 15  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 16  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                     Off-centered hours and minutes
# 21                     Off-centered hours and minutes
# 22                     Off-centered hours and minutes
# 23  Singing bird action\r\n15 jewels\r\nOff-center...
# 24       Off-centered hours and minutes at 12 o'clock
# 25                     Off-centered hours and minutes
# 26                     Off-centered hours and minutes
# 27                     Centered hours and minutes\r\n
# 28                                               None
# 29                                               None
# 30  Off-centered hours and minutes Off-centered to...
# 31  Off-centered hours and minutes at 6 o'clock. T...
# 32  Off-centered hours and minutes at 6 o'clock. T...
# 33  Off-centered hours and minutes at 6 o'clock. T...
# 34  Off-centered hours and minutes at 6 o'clock. T...
# 35  Off-centered hours and minutes, large seconds ...
# 36  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 37  Hours and minutes at 6 o'clock\r\nTourbillon f...
# 38      Listed under "Technical Data" > "Indications"
#
#                                           description short_description
# 0   Black onyx dial and 18-karat red gold applied ...
# 1   Sapphire dial with metallic sapphire base. \r\...
# 2   Hand-engraved and hand-painted 18-karat gold d...
# 3   Sapphire dial and light metallic sapphire base...
# 4   Sapphire dial and base. \r\nSapphire case. \r\...
# 5   Onyx dial and subdial, mountain decor in 18-ka...
# 6   Black onyx and white mother-of-pearl dial with...
# 7   Sapphire dial.\r\n18-carat white gold case.\r\...
# 8   Chinchilla red petrified wood and black onyx d...
# 9   Hand-engraved and hand-painted white mother-of...
# 10  Hand-engraved and hand-painted white mother-of...
# 11  Grand Feu enamel dial. \r\n18-karat white gold...
# 12  18-karat white gold and opal dial, black onyx ...
# 13  Red Grand Feu paillonné-enameled dial. \r\nSil...
# 14  Ivory Grand Feu enameled dial.\r\n18-carat red...
# 15  Ivory Grand Feu enamel, tourbillon frame. 18-c...
# 16  Black dial with rubber treatment.\r\n18-carat ...
# 17  Hand-polished and satin-brushed stainless stee...
# 18  Hand-wound mechanical automaton, hand-painted ...
# 19  Hand-wound mechanical automaton, hand-painted ...
# 20  Black onyx dial and 18-karat red gold applied ...
# 21  Hand-engraved and hand-painted white mother-of...
# 22  Onyx dial and subdial, mountain decor in 18-ka...
# 23  Sapphire dial.\r\n18-carat white gold case.\r\...
# 24  Chinchilla red petrified wood and black onyx d...
# 25  Hand-engraved and hand-painted white mother-of...
# 26  Hand-engraved and hand-painted white mother-of...
# 27  18-carat red gold, guilloché dial. 18-carat re...
# 28  Hand-polished and satin-brushed stainless stee...
# 29  Hand-wound mechanical automaton, hand-painted ...
# 30  Red Grand Feu paillonné-enameled dial. \r\nSil...
# 31  Sapphire dial with metallic sapphire base. \r\...
# 32  Hand-engraved and hand-painted 18-karat gold d...
# 33  Sapphire dial and light metallic sapphire base...
# 34  Sapphire dial and base. \r\nSapphire case. \r\...
# 35  Ivory Grand Feu enameled dial.\r\n18-carat red...
# 36  Ivory Grand Feu enameled dial.\r\n18-carat red...
# 37  Black dial with rubber treatment.\r\n18-carat ...
# 38  Main product description (before you click Tec...
#
# [39 rows x 40 columns]

# %%
df_watches_data.to_csv('df.csv', index=False, encoding='utf-8-sig')
